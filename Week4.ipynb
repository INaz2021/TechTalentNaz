# %%
#Task 1:
#How many rows and columns are there in your file
import pandas as pd
data = pd.read_csv("15Destination.csv")
data.shape
#print(data)
# Out:
# (15, 5)

# %%
#Task 2:
#Print row 3-8 ( using iloc/loc)
data = pd.read_csv("15Destination.csv")
print(data.iloc[3:9])
# Out:
#           Destination  Feedback(1-10)  AvgRating  No_of_Hotels  \
# 3           Yorkshire               8          3            16
# 4       Isle Of Wight               4          2            10
# 5  Scottish Highlands               8          5             6
# 6      Jurassic Coast               3          4             5
# 7           Cotswolds               1          2            14
# 8            Hebrides               4          2             7
#
#   Most_Visited_Place
# 3               g, h
# 4               i, j
# 5                  k
# 6                l,m
# 7               n, o
# 8                  p

# %%
#Task 3
#Find the mean number of all-inclusive hotels across all destinations
data = pd.read_csv("15Destination.csv")
data['No_of_Hotels'].mean()
# Out:
# 12.466666666666667

# %%
#Task 4
#Find the lowest scoring destination.
data = pd.read_csv("15Destination.csv")
data.loc[data.Feedback_Score].min()
# Out:
# Destination           Belfast
# Feedback_Score              1
# AvgRating                   2
# No_of_Hotels                5
# Most_Visited_Place       d, e
# dtype: object

# %%
#Task 5
#Find the highest scoring destination
data = pd.read_csv("15Destination.csv")
data.loc[data.Feedback_Score].max()
# Out:
# Destination           Yorkshire
# Feedback_Score               10
# AvgRating                     5
# No_of_Hotels                 16
# Most_Visited_Place          r,s
# dtype: object

# %%
#Task 6
#Find all the destinations where there are more than 9 all-inclusive hotels
data = pd.read_csv("15Destination.csv")
data.loc[data.No_of_Hotels > 9]
# Out:
#       Destination  Feedback(1-10)  AvgRating  No_of_Hotels Most_Visited_Place
# 0   Lake District              10          5            10            a, b, c
# 1   Peak District               9          5            15               d, e
# 3       Yorkshire               8          3            16               g, h
# 4   Isle Of Wight               4          2            10               i, j
# 7       Cotswolds               1          2            14               n, o
# 10        Belfast               7          3            12                r,s
# 11           Kent               5          3            30                  t
# 12        Norfolk               8          4            10                u,v
# 13         London               9          5            25                w,x
# 14         Sussex               8          5            14                y,z

# %%
# Task 7
#Filter the data by score above 8
data = pd.read_csv("15Destination.csv")
data.loc[data.Feedback_Score > 8]
# Out:
#       Destination  Feedback_Score  AvgRating  No_of_Hotels Most_Visited_Place
# 0   Lake District              10          5            10            a, b, c
# 1   Peak District               9          5            15               d, e
# 9     North Wales              10          4             5                  q
# 13         London               9          5            25                w,x

# %%
#Task 8
#Filter the data score below 2 ( I need to know if these destinations should be removed or there is a problem)
data = pd.read_csv("15Destination.csv")
data.loc[data.Feedback_Score < 2]
# Out:
#   Destination  Feedback_Score  AvgRating  No_of_Hotels Most_Visited_Place
# 7   Cotswolds               1          2            14               n, o

# %%
#Task 9
#Create a data visualisation diagram to show destination and highest scores
data = pd.read_csv("15Destination.csv")
data.plot.line(x='Destination', y = "Feedback_Score", figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Destination'>
